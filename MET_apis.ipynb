# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import os

# %%
requests.get("https://collectionapi.metmuseum.org/public/collection/v1/objects?departmentIds=13")

response_IDs =  requests.get("https://collectionapi.metmuseum.org/public/collection/v1/objects?departmentIds=13")

response_IDs.json()
# Out:
# {'total': 33674,
#  'objectIDs': [240501,
#   240502,
#   240503,
#   240504,
#   240505,
#   240506,
#   240507,
#   240508,
#   240509,
#   240510,
#   240511,
#   240512,
#   240513,
#   240514,
#   240515,
#   240516,
#   240517,
#   240518,
#   240519,
#   240520,
#   240521,
#   240522,
#   240523,
#   240524,
#   240525,
#   240526,
#   240527,
#   240528,
#   240529,
#   240530,
#   240531,
#   240532,
#   240533,
#   240534,
#   240535,
#   240536,
#   240537,
#   240538,
#   240539,
#   240540,
#   240541,
#   240542,
#   240543,
#   240544,
#   240545,
#   240546,
#   240547,
#   240548,
#   240549,
#   240550,
#   240551,
#   240552,
#   240553,
#   240554,
#   240555,
#   240556,
#   240557,
#   240558,
#   240559,
#   240560,
#   240561,
#   240562,
#   240563,
#   240564,
#   240565,
#   240566,
#   240567,
#   240568,
#   240569,
#   240570,
#   240571,
#   240572,
#   240573,
#   240574,
#   240575,
#   240576,
#   240577,
#   240578,
#   240579,
#   240580,
# ...

# %%
requests.get("https://collectionapi.metmuseum.org/public/collection/v1/search?departmentId=13&q=cat")

response = requests.get("https://collectionapi.metmuseum.org/public/collection/v1/search?departmentId=13&q=rome")

response.json()
# Out:
# {'total': 2027,
#  'objectIDs': [248157,
#   246280,
#   251120,
#   246006,
#   245860,
#   246431,
#   248140,
#   247875,
#   253569,
#   251821,
#   246880,
#   248132,
#   251473,
#   251411,
#   248153,
#   251474,
#   258540,
#   248059,
#   246875,
#   251929,
#   247117,
#   248899,
#   256403,
#   246700,
#   245834,
#   245836,
#   245837,
#   248783,
#   245833,
#   245832,
#   248467,
#   248139,
#   248141,
#   245839,
#   245831,
#   258542,
#   251037,
#   251401,
#   251040,
#   251414,
#   248752,
#   252884,
#   254565,
#   246888,
#   248034,
#   248037,
#   248035,
#   248052,
#   248066,
#   248069,
#   248036,
#   254819,
#   249051,
#   630074,
#   248316,
#   248328,
#   775805,
#   246876,
#   248801,
#   245397,
#   245390,
#   258081,
#   248143,
#   254535,
#   254473,
#   247524,
#   247169,
#   246992,
#   246885,
#   246889,
#   246882,
#   246463,
#   248045,
#   248063,
#   248065,
#   248064,
#   248067,
#   248032,
#   248466,
#   249223,
# ...
