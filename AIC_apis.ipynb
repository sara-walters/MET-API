# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import os

# %%
requests.get("https://api.artic.edu/api/v1/artworks/129884")

response_test = requests.get("https://api.artic.edu/api/v1/artworks/129884")

response_test.json()
# Out:
# {'data': {'id': 129884,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/129884',
#   'is_boosted': True,
#   'title': 'Starry Night and the Astronauts',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 5376,
#    'height': 6112,
#    'alt_text': 'Abstract painting composed of small vertical dabs of multiple shades of blue with a small area of similar strokes of red, orange, and yellow in the upper right.'},
#   'main_reference_number': '1994.36',
#   'has_not_been_viewed_much': False,
#   'boost_rank': 1,
#   'date_start': 1972,
#   'date_end': 1972,
#   'date_display': '1972',
#   'date_qualifier_title': '',
#   'date_qualifier_id': None,
#   'artist_display': 'Alma Thomas\nAmerican, 1891–1978',
#   'place_of_origin': 'United States',
# ...

# %%
requests.get("https://api.artic.edu/api/v1/artworks/search?q=roman")
# Out:
# <Response [200]>

# %%
response = requests.get("https://api.artic.edu/api/v1/artworks/search?q=roman")

response.json()
# Out:
# {'preference': None,
#  'pagination': {'total': 2005,
#   'limit': 10,
#   'offset': 0,
#   'total_pages': 201,
#   'current_page': 1},
#  'data': [{'_score': 112.41022,
#    'id': 61600,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/61600',
#    'is_boosted': False,
#    'title': 'Statue of the Aphrodite of Knidos',
#    'thumbnail': {'lqip': '...',
#     'width': 5412,
#     'height': 7216,
#     'alt_text': 'White and beige stone statue of a female nude standing in contrapposto position, with weight on the right leg. The head of the statue is missing. The left arm has been broken off just past the shoulder, and the left hand is also absent.'},
#    'timestamp': '2025-04-13T23:25:30-05:00'},
#   {'_score': 111.24508,
#    'id': 9978,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/9978',
#    'is_boosted': False,
#    'title': 'Denarius (Coin) Depicting the God Apollo',
#    'thumbnail': {'lqip': '...',
# ...
